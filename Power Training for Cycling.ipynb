# %% [markdown]
# # Power Training for Cycling

# %% [markdown]
# #### Functional Threshold Power (FTP)
#
# 能夠穩定持續輸出一小時的最大功率
#
# 或者，
#
# 能夠穩定持續輸出20分鐘的最大功率乘以0.95

# %% [markdown]
# #### 強度區間
#
# | Zone | % of FTP | Purpose   | Duration (min) | times per week |
# | ---- | -------- | --------- | -------------- | -------------- |
# | 1    | < 55%    | 主動恢復   | 30 ~ 90        | 1 ~ 3          |
# | 2    | < 75%    | 有氧耐力   | 60 ~ 360       | 1 ~ 4          |
# | 3    | < 90%    | 強有氧耐力 | 60 ~ 180        | 1 ~ 3          |
# | 4    | < 105%   | 乳酸閾值   | 8 ~ 30         | 1 ~ 3          |
# | 5    | < 120%   | 最大攝氧量 | 3 ~ 8           | 1 ~ 2          |
# | 6    | < 150%   | 無氧耐力   | 0.5 ~ 3         | 1 ~ 2          |
# | 7    | 全力衝刺  | 衝刺能力   |  < 0.5          | 1 ~ 2          |

# %% [markdown]
# #### 最大平均功率
#
# |         | 衝刺能力 (5sec) | 無氧能力 (60sec) | 最大有氧能力 (5min) | 乳酸閾值 (20min) |
# | ------- | -------------- | --------------- | ----------------- | -------------- |
# | Watt/Kg | S              |  A              | V                 | F              |
#
# - 全能型：SAVF 排名平均。
# - 衝刺型：SA 特別好，適合短距離賽，但是仍需要訓練有氧能力。
# - 爬坡型：VF 特別好，適合個人計時賽、爬坡賽、鐵人三項。
# - 短途場地型：AV 特別好，適合一公里計時賽、個人追逐賽。
# - 欠操型：SF 特別好，表示有潛力還沒發揮。

# %% [markdown]
# #### 功率衰退程度 (FP, Fatigue Profile)
#
# 計算不同時間長度下平均功率衰退的程度。

# %% [markdown]
# #### 標準化功率 Normalized Power (NP)
#
# NP = $(\frac{\sum_{i=1}^{N}{P_i^4}}{N})^{0.25}$

# %% [markdown]
# #### 強度係數 Intensity Factor (IF)
#
# IF = $\frac{NP}{FTP}$

# %% [markdown]
# #### 變動指數 Variance Index (VI)
#
# Average Power = $P_{avg} =\frac{\sum_{i=1}^{N}{P_i}}{N}$
#
# VI = $\frac{NP}{P_{avg}}$

# %% [markdown]
# #### 訓練壓力指數 Training Stress Score (TSS)
# $ TSS = 100 \times \frac{Hour \times NP \times IF}{FTP}$
# $ = 100 \times (\frac{NP}{FTP})^2 \times Hour$

# %% [markdown]
# #### 象限分析 Quadant Analysis
#
# |  | Low Cadence <br> (T-Cadence 以下) | High Cadence <br> (T-Cadence 以上)|
# | --- | --- | --- |
# | High Power <br> (FTP 以上) |Q II <br> 重齒比| Q I <br> 衝刺 |
# | Low Power <br> (FTP 以下) |Q III <br> 恢復 | Q IV <br> 輕齒比 |
#
# **T-Cadence : ** Threshold Cadence 臨界迴轉速，FTP測試時的平均迴轉速。

# %% [markdown]
# #### 效率係數 Efficiency Factor (EF)
#
# $ EF = \frac{NP}{HR_{avg}} $
#
# **HR :** Heart Rate

# %% [markdown]
# ### Other WKO Parameters
# Reference :
#     [WKO4 Definition](http://www.wko4help.com/terms-and-definitions)

# %% [markdown]
# #### CIL : Chronic Intensity Load 長期訓練強度
# To see the trend of Intensity Factor
#
# $CIL_t = (1000 \times IF) \times 0.0235 + CIL_{t-1} \times 0.9765$
#
# $1-e^{(-1/42)} = 0.0235$
#
# $e^{(-1/42)} = 0.9765$

# %% [markdown]
# #### CTL : Chronic Training Load 長期訓練量
#
# $CTL = Average_{6 weeks}(TSS)$
#
# Normal : 25 ~ 145

# %% [markdown]
# #### ATL : Acute Training Load 短期訓練量
#
# $ATL = Average_{7 days}(TSS)$
#
# Normal : 20 ~ 90

# %% [markdown]
# #### TSB : Training Stress Balance 訓練壓力平衡指數
#
# $ TSB = f(ATL - CTL) $
#
# Normal : 5 ~ 25

# %% [markdown]
# #### RR : Ramp Rate 訓練量增加率
#
# $ RR = f(\Delta CTL) $

# %% [markdown]
# #### PMAX : Maximal Power 最大功率

# %% [markdown]
# #### FRC : Functional Reserve Capacity 無氧儲備能力
# 輸出功率超過FTP時所能維持的總做功能力，單位 KJ
#
# $FRC = \int P dt \div 1000$
#
# (P: Watt, t: Sec, FRC: kJ)
#
# （男性 23 KJ 以上為優秀，女性大約為男性的75%）

# %% [markdown]
# #### mFTP : Modeled FTP
# 根據過去90天功率-時間曲線推算的FTP。（90天內騎乘30~60 min的資料中的最大平均功率）
#
# #### sFTP : Set FTP
# 使用者手動輸入的 FTP

# %% [markdown]
# #### Stamina 續航力
# 在一個小時之後Power衰退的程度。
#
# 假想的公式：
# $ (1-\frac{P_{60 } - P_{120}}{P_{60}}) \times 100\% $
#
# 自行車手約 75 ~ 85%
#
# [WKO4 Training Metrics: Introducing Stamina](https://www.trainingpeaks.com/blog/wko4-training-metrics-introducing-stamina/)

# %% [markdown]
# #### VAM : Average Ascent Speed 平均爬升速度
#
# VAM = Climb Height / time
#
# (VAM: m/hour, Climb Height: meter time: hour)

# %% [markdown]
# #### AEPF : Average Effective Pedal Force 平均有效踩踏力量
#
# AEPF = $ (P \times 60) / (Cadence \times 2\pi \times R)$
#
# R: Crank length
#
# #### MEPF Maximum Effective Pedal Force 最大有效踩踏力量
#
# MEPF = $ (P_{max} \times 60) / (Cadence_i \times 2\pi \times R)$

# %% [markdown]
# ### FIT Analyzer
# Input : fit file, mFTP
#
# Output : Pavg, NP, IF, VI, TSS, and the plots
#
# (Please install the package: [fitparse](https://github.com/dtcooper/python-fitparse) )

# %%
###############################################################################
# fit analyzer
# pip install fitparse
# https://github.com/dtcooper/python-fitparse
###############################################################################
import sys
import os
import matplotlib.pyplot as plt
import numpy as np
from fitparse import FitFile
###############################################################################
# filename ="2018-06-20-15-24-48.fit"
# filename = "2018-05-06-07-51-20.fit"
filename = str(input("Enter fit file name (xxx.fit):"))

fitfile_path = os.path.join("",filename)
fitfile = FitFile(fitfile_path)
fitfile.parse()
records = list(fitfile.get_messages(name='record'))
###############################################################################
ftp = float(input("Input Your FTP? (Watt)"))
if ftp < 10.0 :
    ftp = 10.0
    print("Come on, you are not that weak! That's say your FTP is 10.0 W")

timestamp = []
position_lat = []
position_long = []
distance = []
altitude = []
speed = []
power = []
cadence = []
# temperature = []
# left_right_balance = []
cnt = 0
sum_p = 0.0
sum_p4 = 0.0
###############################################################################
def rolling_avg(data_array,length):
    if len(data_array) > length :
        return np.sum(data_array[-length:-1])/len(data_array[-length:-1])
    elif len(data_array) > 1 :
        return np.sum(data_array)/len(data_array)
    else:
        return data_array[-1]
###############################################################################
# readout : read a field from slice and put it to data_array
def readout(slice,field,data_array):
    data = slice.get(field_name = field)

    if data == None :
        if len(data_array) > 0 :
            data_array.append(data_array[-1])
        else:
            # print("[{}] No data at beginning of {}".format(cnt,field))
            if (field == "position_lat") or (field == "position_long") :
                pass
            else :
                data_array.append(0.0)

    elif data.value == None :
        if len(data_array) > 0 :
            data_array.append(data_array[-1])
        else:
            # print("[{}] Empty data at beginning of {}".format(cnt,field))
            if (field == "position_lat") or (field == "position_long") :
                pass
            else :
                data_array.append(0.0)
    else:
        data_array.append(float(data.value))

###############################################################################
# Main loop
for rec in records:
    timestamp.append(rec.get(field_name='timestamp'))
    readout(rec,"position_lat",position_lat)
    readout(rec,"position_long",position_long)
    readout(rec,"distance",distance)
    readout(rec,"altitude",altitude)
    readout(rec,"speed",speed)
    readout(rec,"power",power)
    readout(rec,"cadence",cadence)

    sum_p = sum_p + power[-1]
    sum_p4 = sum_p4 + pow(rolling_avg(power,30),4)

    cnt = cnt + 1
###############################################################################
# Calculation
average_power = (sum_p/len(power))
normalized_power = pow(sum_p4 / len(power),0.25)
if average_power < 0.1 :
    intensity_factor = ftp * 10.0
    vi = normalized_power * 10.0
else:
    intensity_factor = normalized_power / ftp
    vi = normalized_power / average_power

tss = 100*(cnt/3600) * normalized_power * intensity_factor / (ftp)

report_str0 = filename
report_str1 = " FTP : {:.0f}, Pavg : {:.0f}, NP : {:.0f},".format(ftp,average_power,normalized_power)
report_str2 = " IF : {:.3f}, VI : {:.2f}, TSS : {:.1f}".format(intensity_factor,vi,tss)
print("------------------------------------------------------")
print(filename)
print(report_str1 + report_str2)
print("------------------------------------------------------")
###############################################################################
# Plot
fig1 = plt.figure(figsize=(8, 6), dpi=80)
t = np.arange(0., len(timestamp), 1.0)
plt.subplot(411)
title_str = "{}\n {} {}".format(filename,report_str1,report_str2)
plt.title(title_str)
plt.plot(t,altitude,'b',alpha=0.5,label='Altitude')
plt.ylabel('altitude')
plt.legend()
plt.grid(True)

plt.subplot(412)
plt.plot(t,speed,'r',alpha=0.5,label='Speed')
plt.ylabel('speed (m/s)')
plt.legend()
plt.grid(True)

plt.subplot(413)
plt.plot(t,cadence,'g',alpha=0.5,label='Cadence')
plt.ylabel('Cadence')
plt.legend()
plt.grid(True)

plt.subplot(414)
plt.plot(t,power,'b',alpha=0.5,label='Power')
plt.plot([t[0],t[-1]],[normalized_power,normalized_power],'r-',alpha=0.5,label='NP')
plt.plot([t[0],t[-1]],[average_power,average_power],'g-',alpha=0.5,label='Pavg')
plt.ylabel('Power')
plt.legend()
plt.grid(True)
plt.tight_layout(True)
plt.show(block = True)
ofilename = "{}-FTP{}.png".format(filename,ftp).replace('/','-')
fig1.savefig(ofilename, bbox_inches='tight')
###############################################################################
fig2 = plt.figure(figsize=(8, 8), dpi=80)
title_str2 = "{}".format(filename)
plt.plot(position_long[1:],position_lat[1:],'go',alpha=0.5,label='Coordinate')
plt.xlabel("Longitude")
plt.ylabel("Latitude")
# plt.legend()
plt.grid(True)

plt.tight_layout(True)
plt.show(block = True)
ofilename = "{}-dist.png".format(filename).replace('/','-')
fig2.savefig(ofilename, bbox_inches='tight')
# Out:
# Enter fit file name (xxx.fit):2018-05-06-07-51-20.fit
# Input Your FTP? (Watt)200
# ------------------------------------------------------
# 2018-05-06-07-51-20.fit
#  FTP : 200, Pavg : 87, NP : 150, IF : 0.752, VI : 1.72, TSS : 122.2
# ------------------------------------------------------
